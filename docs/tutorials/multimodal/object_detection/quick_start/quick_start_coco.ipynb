# %% [markdown]
# # AutoMM Detection - Quick Start on a Tiny COCO Format Dataset
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/autogluon/autogluon/blob/master/docs/tutorials/multimodal/object_detection/quick_start/quick_start_coco.ipynb)
# [![Open In SageMaker Studio Lab](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github/autogluon/autogluon/blob/master/docs/tutorials/multimodal/object_detection/quick_start/quick_start_coco.ipynb)
#
#
#
# In this section, our goal is to fast finetune a pretrained model on a small dataset in COCO format,
# and evaluate on its test set. Both training and test sets are in COCO format.
# See [Convert Data to COCO Format](../data_preparation/convert_data_to_coco_format.ipynb) for how to convert other datasets to COCO format.
#
# ## Setting up the imports
# To start, let's import MultiModalPredictor:

# %%
# !pip install autogluon.multimodal
# Out:
# Requirement already satisfied: autogluon.multimodal in /opt/conda/envs/pytorch/lib/python3.9/site-packages (0.8.2)
# Requirement already satisfied: pandas<1.6,>=1.4.1 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (1.4.4)
# Requirement already satisfied: accelerate<0.17,>=0.9 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (0.16.0)
# Requirement already satisfied: pytorch-lightning<1.10.0,>=1.9.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (1.9.5)
# Requirement already satisfied: requests<3,>=2.21 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (2.28.2)
# Requirement already satisfied: tqdm<5,>=4.38 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (4.65.2)
# Requirement already satisfied: scipy<1.12,>=1.5.4 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (1.8.1)
# Requirement already satisfied: evaluate<0.4.0,>=0.2.2 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (0.3.0)
# Requirement already satisfied: timm<0.10.0,>=0.9.2 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (0.9.7)
# Requirement already satisfied: scikit-image<0.20.0,>=0.19.1 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (0.19.3)
# Requirement already satisfied: scikit-learn<1.3,>=1.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (1.0)
# Requirement already satisfied: text-unidecode<1.4,>=1.3 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (1.3)
# Requirement already satisfied: autogluon.features==0.8.2 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (0.8.2)
# Requirement already satisfied: nlpaug<1.2.0,>=1.1.10 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (1.1.11)
# Requirement already satisfied: autogluon.common==0.8.2 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (0.8.2)
# Requirement already satisfied: Pillow<9.6,>=9.3 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (9.5.0)
# Requirement already satisfied: jsonschema<4.18,>=4.14 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (4.17.3)
# Requirement already satisfied: jinja2<3.2,>=3.0.3 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (3.1.2)
# Requirement already satisfied: nltk<4.0.0,>=3.4.5 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (3.8.1)
# Requirement already satisfied: transformers[sentencepiece]<4.27.0,>=4.23.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (4.26.1)
# Requirement already satisfied: pytorch-metric-learning<2.0,>=1.3.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (1.7.3)
# Requirement already satisfied: tensorboard<3,>=2.9 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (2.13.0)
# Requirement already satisfied: torchvision<0.15.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (0.14.1)
# Requirement already satisfied: seqeval<1.3.0,>=1.2.2 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (1.2.2)
# Requirement already satisfied: omegaconf<2.3.0,>=2.1.1 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (2.1.1)
# Requirement already satisfied: nptyping<2.5.0,>=1.4.4 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (2.4.1)
# Requirement already satisfied: openmim<0.4.0,>=0.3.7 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (0.3.9)
# Requirement already satisfied: torchmetrics<0.12.0,>=0.11.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (0.11.4)
# Requirement already satisfied: numpy<1.27,>=1.21 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (1.24.3)
# Requirement already satisfied: autogluon.core[raytune]==0.8.2 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (0.8.2)
# Requirement already satisfied: boto3<2,>=1.10 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (1.26.142)
# Requirement already satisfied: pytesseract<0.3.11,>=0.3.9 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (0.3.10)
# Requirement already satisfied: defusedxml<0.7.2,>=0.7.1 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (0.7.1)
# Requirement already satisfied: torch<1.14,>=1.9 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.multimodal) (1.13.1)
# Requirement already satisfied: setuptools in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.common==0.8.2->autogluon.multimodal) (60.2.0)
# Requirement already satisfied: psutil<6,>=5.7.3 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.common==0.8.2->autogluon.multimodal) (5.9.5)
# Requirement already satisfied: matplotlib in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.core[raytune]==0.8.2->autogluon.multimodal) (3.5.3)
# Requirement already satisfied: networkx<4,>=3.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.core[raytune]==0.8.2->autogluon.multimodal) (3.1)
# Requirement already satisfied: hyperopt<0.2.8,>=0.2.7 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.core[raytune]==0.8.2->autogluon.multimodal) (0.2.7)
# Requirement already satisfied: ray[tune]<2.4,>=2.3 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from autogluon.core[raytune]==0.8.2->autogluon.multimodal) (2.3.1)
# Requirement already satisfied: pyyaml in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from accelerate<0.17,>=0.9->autogluon.multimodal) (6.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from accelerate<0.17,>=0.9->autogluon.multimodal) (21.3)
# Requirement already satisfied: botocore<1.30.0,>=1.29.142 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from boto3<2,>=1.10->autogluon.multimodal) (1.29.142)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from boto3<2,>=1.10->autogluon.multimodal) (0.10.0)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from boto3<2,>=1.10->autogluon.multimodal) (0.6.1)
# Requirement already satisfied: multiprocess in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from evaluate<0.4.0,>=0.2.2->autogluon.multimodal) (0.70.14)
# Requirement already satisfied: responses<0.19 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from evaluate<0.4.0,>=0.2.2->autogluon.multimodal) (0.18.0)
# Requirement already satisfied: datasets>=2.0.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from evaluate<0.4.0,>=0.2.2->autogluon.multimodal) (2.14.5)
# Requirement already satisfied: dill in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from evaluate<0.4.0,>=0.2.2->autogluon.multimodal) (0.3.6)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from evaluate<0.4.0,>=0.2.2->autogluon.multimodal) (0.15.1)
# Requirement already satisfied: xxhash in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from evaluate<0.4.0,>=0.2.2->autogluon.multimodal) (3.4.1)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from evaluate<0.4.0,>=0.2.2->autogluon.multimodal) (2023.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from jinja2<3.2,>=3.0.3->autogluon.multimodal) (2.1.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from jsonschema<4.18,>=4.14->autogluon.multimodal) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from jsonschema<4.18,>=4.14->autogluon.multimodal) (23.1.0)
# Requirement already satisfied: gdown>=4.0.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from nlpaug<1.2.0,>=1.1.10->autogluon.multimodal) (4.7.1)
# Requirement already satisfied: click in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from nltk<4.0.0,>=3.4.5->autogluon.multimodal) (8.1.3)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from nltk<4.0.0,>=3.4.5->autogluon.multimodal) (2023.6.3)
# Requirement already satisfied: joblib in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from nltk<4.0.0,>=3.4.5->autogluon.multimodal) (1.2.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.0.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from nptyping<2.5.0,>=1.4.4->autogluon.multimodal) (4.6.2)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from omegaconf<2.3.0,>=2.1.1->autogluon.multimodal) (4.8)
# Requirement already satisfied: opendatalab in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal) (0.0.10)
# Requirement already satisfied: colorama in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal) (0.4.3)
# Requirement already satisfied: tabulate in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal) (0.9.0)
# Requirement already satisfied: rich in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal) (13.4.2)
# Requirement already satisfied: pip>=19.3 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal) (22.3.1)
# Requirement already satisfied: model-index in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal) (0.1.11)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from pandas<1.6,>=1.4.1->autogluon.multimodal) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from pandas<1.6,>=1.4.1->autogluon.multimodal) (2023.3)
# Requirement already satisfied: lightning-utilities>=0.6.0.post0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from pytorch-lightning<1.10.0,>=1.9.0->autogluon.multimodal) (0.9.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from requests<3,>=2.21->autogluon.multimodal) (2023.5.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from requests<3,>=2.21->autogluon.multimodal) (3.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from requests<3,>=2.21->autogluon.multimodal) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from requests<3,>=2.21->autogluon.multimodal) (3.4)
# Requirement already satisfied: imageio>=2.4.1 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from scikit-image<0.20.0,>=0.19.1->autogluon.multimodal) (2.31.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from scikit-image<0.20.0,>=0.19.1->autogluon.multimodal) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from scikit-image<0.20.0,>=0.19.1->autogluon.multimodal) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from scikit-learn<1.3,>=1.0->autogluon.multimodal) (3.1.0)
# Requirement already satisfied: protobuf>=3.19.6 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from tensorboard<3,>=2.9->autogluon.multimodal) (3.20.2)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from tensorboard<3,>=2.9->autogluon.multimodal) (3.4.3)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from tensorboard<3,>=2.9->autogluon.multimodal) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from tensorboard<3,>=2.9->autogluon.multimodal) (1.56.0)
# Requirement already satisfied: wheel>=0.26 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from tensorboard<3,>=2.9->autogluon.multimodal) (0.40.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from tensorboard<3,>=2.9->autogluon.multimodal) (0.7.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from tensorboard<3,>=2.9->autogluon.multimodal) (1.0.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from tensorboard<3,>=2.9->autogluon.multimodal) (2.21.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from tensorboard<3,>=2.9->autogluon.multimodal) (2.3.4)
# Requirement already satisfied: safetensors in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from timm<0.10.0,>=0.9.2->autogluon.multimodal) (0.2.7)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from transformers[sentencepiece]<4.27.0,>=4.23.0->autogluon.multimodal) (0.12.1)
# Requirement already satisfied: filelock in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from transformers[sentencepiece]<4.27.0,>=4.23.0->autogluon.multimodal) (3.12.4)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from transformers[sentencepiece]<4.27.0,>=4.23.0->autogluon.multimodal) (0.1.99)
# Requirement already satisfied: pyarrow>=8.0.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate<0.4.0,>=0.2.2->autogluon.multimodal) (12.0.0)
# Requirement already satisfied: aiohttp in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate<0.4.0,>=0.2.2->autogluon.multimodal) (3.8.4)
# Requirement already satisfied: six in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal) (4.12.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.9->autogluon.multimodal) (0.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.9->autogluon.multimodal) (5.3.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.9->autogluon.multimodal) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<3,>=2.9->autogluon.multimodal) (1.3.1)
# Requirement already satisfied: cloudpickle in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[raytune]==0.8.2->autogluon.multimodal) (2.2.1)
# Requirement already satisfied: py4j in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[raytune]==0.8.2->autogluon.multimodal) (0.10.9.7)
# Requirement already satisfied: future in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[raytune]==0.8.2->autogluon.multimodal) (0.18.3)
# Requirement already satisfied: importlib-metadata>=4.4 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<3,>=2.9->autogluon.multimodal) (4.13.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from packaging>=20.0->accelerate<0.17,>=0.9->autogluon.multimodal) (3.0.9)
# Requirement already satisfied: frozenlist in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from ray[tune]<2.4,>=2.3->autogluon.core[raytune]==0.8.2->autogluon.multimodal) (1.3.3)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from ray[tune]<2.4,>=2.3->autogluon.core[raytune]==0.8.2->autogluon.multimodal) (1.0.7)
# Requirement already satisfied: virtualenv>=20.0.24 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from ray[tune]<2.4,>=2.3->autogluon.core[raytune]==0.8.2->autogluon.multimodal) (20.24.5)
# Requirement already satisfied: aiosignal in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from ray[tune]<2.4,>=2.3->autogluon.core[raytune]==0.8.2->autogluon.multimodal) (1.3.1)
# Requirement already satisfied: tensorboardX>=1.9 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from ray[tune]<2.4,>=2.3->autogluon.core[raytune]==0.8.2->autogluon.multimodal) (2.6.2.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from matplotlib->autogluon.core[raytune]==0.8.2->autogluon.multimodal) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from matplotlib->autogluon.core[raytune]==0.8.2->autogluon.multimodal) (4.39.4)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from matplotlib->autogluon.core[raytune]==0.8.2->autogluon.multimodal) (0.11.0)
# Requirement already satisfied: ordered-set in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from model-index->openmim<0.4.0,>=0.3.7->autogluon.multimodal) (4.1.0)
# Requirement already satisfied: pycryptodome in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal) (3.18.0)
# Requirement already satisfied: openxlab in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal) (0.0.28)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal) (2.15.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal) (3.0.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate<0.4.0,>=0.2.2->autogluon.multimodal) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate<0.4.0,>=0.2.2->autogluon.multimodal) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate<0.4.0,>=0.2.2->autogluon.multimodal) (1.9.2)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<3,>=2.9->autogluon.multimodal) (3.15.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal) (0.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<3,>=2.9->autogluon.multimodal) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<3,>=2.9->autogluon.multimodal) (3.2.2)
# Requirement already satisfied: platformdirs<4,>=3.9.1 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from virtualenv>=20.0.24->ray[tune]<2.4,>=2.3->autogluon.core[raytune]==0.8.2->autogluon.multimodal) (3.11.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from virtualenv>=20.0.24->ray[tune]<2.4,>=2.3->autogluon.core[raytune]==0.8.2->autogluon.multimodal) (0.3.7)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from beautifulsoup4->gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal) (2.3.2.post1)
# Requirement already satisfied: oss2~=2.17.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal) (2.17.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from requests<3,>=2.21->autogluon.multimodal) (1.7.1)
# Requirement already satisfied: aliyun-python-sdk-kms>=2.4.1 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal) (2.16.2)
# Requirement already satisfied: aliyun-python-sdk-core>=2.13.12 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal) (2.14.0)
# Requirement already satisfied: crcmod>=1.7 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal) (1.7)
# Requirement already satisfied: cryptography>=2.6.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal) (40.0.2)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal) (1.15.1)
# Requirement already satisfied: pycparser in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal) (2.21)

# %% [markdown]
# Make sure `mmcv` and `mmdet` are installed:

# %%
# !mim install "mmcv=2.1.0"
# !pip install "mmdet==3.2.0"
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu117/torch1.13.0/index.html
# Requirement already satisfied: mmcv in /opt/conda/envs/pytorch/lib/python3.9/site-packages (2.1.0)
# Requirement already satisfied: mmengine>=0.3.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from mmcv) (0.9.0)
# Requirement already satisfied: yapf in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from mmcv) (0.32.0)
# Requirement already satisfied: pyyaml in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from mmcv) (6.0)
# Requirement already satisfied: packaging in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from mmcv) (21.3)
# Requirement already satisfied: opencv-python>=3 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from mmcv) (4.8.0.74)
# Requirement already satisfied: numpy in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from mmcv) (1.24.3)
# Requirement already satisfied: addict in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from mmcv) (2.4.0)
# Requirement already satisfied: Pillow in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from mmcv) (9.5.0)
# Requirement already satisfied: rich in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from mmengine>=0.3.0->mmcv) (13.4.2)
# Requirement already satisfied: matplotlib in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from mmengine>=0.3.0->mmcv) (3.5.3)
# Requirement already satisfied: termcolor in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from mmengine>=0.3.0->mmcv) (2.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from packaging->mmcv) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from matplotlib->mmengine>=0.3.0->mmcv) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from matplotlib->mmengine>=0.3.0->mmcv) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from matplotlib->mmengine>=0.3.0->mmcv) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from matplotlib->mmengine>=0.3.0->mmcv) (4.39.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from rich->mmengine>=0.3.0->mmcv) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from rich->mmengine>=0.3.0->mmcv) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.3.0->mmcv) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.3.0->mmcv) (1.16.0)
# Collecting mmdet==3.2.0
#   Using cached mmdet-3.2.0-py3-none-any.whl (2.1 MB)
# Requirement already satisfied: matplotlib in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from mmdet==3.2.0) (3.5.3)
# Requirement already satisfied: numpy in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from mmdet==3.2.0) (1.24.3)
# Requirement already satisfied: scipy in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from mmdet==3.2.0) (1.8.1)
# Requirement already satisfied: terminaltables in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from mmdet==3.2.0) (3.1.10)
# Requirement already satisfied: shapely in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from mmdet==3.2.0) (2.0.2)
# Requirement already satisfied: six in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from mmdet==3.2.0) (1.16.0)
# Requirement already satisfied: tqdm in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from mmdet==3.2.0) (4.65.2)
# Requirement already satisfied: pycocotools in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from mmdet==3.2.0) (2.0.6)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from matplotlib->mmdet==3.2.0) (4.39.4)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from matplotlib->mmdet==3.2.0) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from matplotlib->mmdet==3.2.0) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from matplotlib->mmdet==3.2.0) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from matplotlib->mmdet==3.2.0) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from matplotlib->mmdet==3.2.0) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from matplotlib->mmdet==3.2.0) (9.5.0)
# Installing collected packages: mmdet
#   Attempting uninstall: mmdet
#     Found existing installation: mmdet 3.1.0
#     Uninstalling mmdet-3.1.0:
#       Successfully uninstalled mmdet-3.1.0
# Successfully installed mmdet-3.2.0

# %%
from autogluon.multimodal import MultiModalPredictor

# %% [markdown]
# And also import some other packages that will be used in this tutorial:

# %%
import os
import time

from autogluon.core.utils.loaders import load_zip

# %% [markdown]
# ## Downloading Data
# We have the sample dataset ready in the cloud. Let's download it:

# %%
zip_file = "https://automl-mm-bench.s3.amazonaws.com/object_detection_dataset/tiny_motorbike_coco.zip"
download_dir = "./tiny_motorbike_coco"

load_zip.unzip(zip_file, unzip_dir=download_dir)
data_dir = os.path.join(download_dir, "tiny_motorbike")
train_path = os.path.join(data_dir, "Annotations", "trainval_cocoformat.json")
test_path = os.path.join(data_dir, "Annotations", "test_cocoformat.json")

# %% [markdown]
# While using COCO format dataset, the input is the json annotation file of the dataset split.
# In this example, `trainval_cocoformat.json` is the annotation file of the train-and-validate split,
# and `test_cocoformat.json` is the annotation file of the test split.
#
# ## Creating the MultiModalPredictor
# We select the `"medium_quality"` presets, which uses a YOLOX-large model pretrained on COCO dataset. This preset is fast to finetune or inference,
# and easy to deploy. We also provide presets `"high_quality"` with a DINO-Resnet50 model and `"best quality"` with a DINO-SwinL model, with much higher performance but also slower and with higher GPU memory usage.

# %%
presets = "medium_quality"

# %% [markdown]
# We create the MultiModalPredictor with selected presets.
# We need to specify the problem_type to `"object_detection"`,
# and also provide a `sample_data_path` for the predictor to infer the catgories of the dataset.
# Here we provide the `train_path`, and it also works using any other split of this dataset.
# And we also provide a `path` to save the predictor.
# It will be saved to a automatically generated directory with timestamp under `AutogluonModels` if `path` is not specified.

# %%
# Init predictor
import uuid

model_path = f"./tmp/{uuid.uuid4().hex}-quick_start_tutorial_temp_save"

predictor = MultiModalPredictor(
    problem_type="object_detection",
    sample_data_path=train_path,
    presets=presets,
    path=model_path,
)

# %% [markdown]
# ## Finetuning the Model
#
# Learning rate, number of epochs, and batch_size are included in the presets, and thus no need to specify.
# Note that we use a two-stage learning rate option during finetuning by default,
# and the model head will have 100x learning rate.
# Using a two-stage learning rate with high learning rate only on head layers makes
# the model converge faster during finetuning. It usually gives better performance as well,
# especially on small datasets with hundreds or thousands of images.
# We also compute the time of the fit process here for better understanding the speed.
# We run it on a g4.2xlarge EC2 machine on AWS,
# and part of the command outputs are shown below:

# %%
start = time.time()
predictor.fit(train_path)  # Fit
train_end = time.time()
# Out:
# Using default root folder: ./tiny_motorbike_coco/tiny_motorbike/Annotations/... Specify `root=...` if you feel it is wrong...
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Global seed set to 0
# AutoMM starts to create your model. ✨
#
# - AutoGluon version is 0.8.2.
#
# - Pytorch version is 1.13.1.
#
# - Model will be saved to "/home/ubuntu/ag/autogluon/docs/tutorials/multimodal/object_detection/quick_start/tmp/ea97b4b870a24b65917cd62fd7296303-quick_start_tutorial_temp_save".
#
# - Validation metric is "map".
#
# - To track the learning progress, you can open a terminal and launch Tensorboard:
#     ```shell
#     # Assume you have installed tensorboard
#     tensorboard --logdir /home/ubuntu/ag/autogluon/docs/tutorials/multimodal/object_detection/quick_start/tmp/ea97b4b870a24b65917cd62fd7296303-quick_start_tutorial_temp_save
#     ```
#
# Enjoy your coffee, and let AutoMM do the job ☕☕☕ Learn more at https://auto.gluon.ai
# Loads checkpoint by local backend from path: yolox_l_8x8_300e_coco_20211126_140236-d3bd2b23.pth
# The model and loaded state dict do not match exactly
#
# size mismatch for bbox_head.multi_level_conv_cls.0.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([10, 256, 1, 1]).
# size mismatch for bbox_head.multi_level_conv_cls.0.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([10]).
# size mismatch for bbox_head.multi_level_conv_cls.1.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([10, 256, 1, 1]).
# size mismatch for bbox_head.multi_level_conv_cls.1.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([10]).
# size mismatch for bbox_head.multi_level_conv_cls.2.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([10, 256, 1, 1]).
# size mismatch for bbox_head.multi_level_conv_cls.2.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([10]).
# /opt/conda/envs/pytorch/lib/python3.9/site-packages/autogluon/multimodal/utils/environment.py:59: UserWarning: Interactive environment is detected. Currently, MultiModalPredictor does not support multi-gpu training under an interactive environment due to the limitation of ddp / ddp_spawn strategies in PT Lightning. Thus, we switch to single gpu training. For multi-gpu training, you need to execute MultiModalPredictor in a script.
#   warnings.warn(
# 8 GPUs are detected, and 1 GPUs will be used.
#    - GPU 0 name: Tesla V100-SXM2-32GB
#    - GPU 0 memory: 33.27GB/34.08GB (Free/Total)
#    - GPU 1 name: Tesla V100-SXM2-32GB
#    - GPU 1 memory: 33.27GB/34.08GB (Free/Total)
#    - GPU 2 name: Tesla V100-SXM2-32GB
#    - GPU 2 memory: 33.27GB/34.08GB (Free/Total)
#    - GPU 3 name: Tesla V100-SXM2-32GB
#    - GPU 3 memory: 33.27GB/34.08GB (Free/Total)
#    - GPU 4 name: Tesla V100-SXM2-32GB
#    - GPU 4 memory: 33.27GB/34.08GB (Free/Total)
#    - GPU 5 name: Tesla V100-SXM2-32GB
#    - GPU 5 memory: 33.27GB/34.08GB (Free/Total)
#    - GPU 6 name: Tesla V100-SXM2-32GB
#    - GPU 6 memory: 33.27GB/34.08GB (Free/Total)
#    - GPU 7 name: Tesla V100-SXM2-32GB
#    - GPU 7 memory: 33.27GB/34.08GB (Free/Total)
# CUDA version is 11.7.
#
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(val_check_interval=1.0)` was configured so validation will run at the end of the training epoch..
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
#   | Name              | Type                             | Params
# -----------------------------------------------------------------------
# 0 | model             | MMDetAutoModelForObjectDetection | 54.2 M
# 1 | validation_metric | MeanAveragePrecision             | 0
# -----------------------------------------------------------------------
# 54.2 M    Trainable params
# 0         Non-trainable params
# 54.2 M    Total params
# 216.620   Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# /opt/conda/envs/pytorch/lib/python3.9/site-packages/mmdet/structures/bbox/base_boxes.py:62: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1670525539683/work/torch/csrc/utils/tensor_new.cpp:230.)
#   data = torch.as_tensor(data)
# /opt/conda/envs/pytorch/lib/python3.9/site-packages/mmdet/structures/bbox/base_boxes.py:62: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1670525539683/work/torch/csrc/utils/tensor_new.cpp:230.)
#   data = torch.as_tensor(data)
# /opt/conda/envs/pytorch/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /opt/conda/conda-bld/pytorch_1670525539683/work/aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Training: 0it [00:00, ?it/s]
# /opt/conda/envs/pytorch/lib/python3.9/site-packages/mmdet/structures/bbox/base_boxes.py:62: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1670525539683/work/torch/csrc/utils/tensor_new.cpp:230.)
#   data = torch.as_tensor(data)
# /opt/conda/envs/pytorch/lib/python3.9/site-packages/mmdet/structures/bbox/base_boxes.py:62: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1670525539683/work/torch/csrc/utils/tensor_new.cpp:230.)
#   data = torch.as_tensor(data)
# Validation: 0it [00:00, ?it/s]
# Epoch 2, global step 6: 'val_map' reached 0.23470 (best 0.23470), saving model to '/home/ubuntu/ag/autogluon/docs/tutorials/multimodal/object_detection/quick_start/tmp/ea97b4b870a24b65917cd62fd7296303-quick_start_tutorial_temp_save/epoch=2-step=6.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 5, global step 12: 'val_map' reached 0.28318 (best 0.28318), saving model to '/home/ubuntu/ag/autogluon/docs/tutorials/multimodal/object_detection/quick_start/tmp/ea97b4b870a24b65917cd62fd7296303-quick_start_tutorial_temp_save/epoch=5-step=12.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 8, global step 18: 'val_map' reached 0.34983 (best 0.34983), saving model to '/home/ubuntu/ag/autogluon/docs/tutorials/multimodal/object_detection/quick_start/tmp/ea97b4b870a24b65917cd62fd7296303-quick_start_tutorial_temp_save/epoch=8-step=18.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 11, global step 24: 'val_map' reached 0.40385 (best 0.40385), saving model to '/home/ubuntu/ag/autogluon/docs/tutorials/multimodal/object_detection/quick_start/tmp/ea97b4b870a24b65917cd62fd7296303-quick_start_tutorial_temp_save/epoch=11-step=24.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 14, global step 30: 'val_map' was not in top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 17, global step 36: 'val_map' reached 0.41027 (best 0.41027), saving model to '/home/ubuntu/ag/autogluon/docs/tutorials/multimodal/object_detection/quick_start/tmp/ea97b4b870a24b65917cd62fd7296303-quick_start_tutorial_temp_save/epoch=17-step=36.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 20, global step 42: 'val_map' reached 0.42072 (best 0.42072), saving model to '/home/ubuntu/ag/autogluon/docs/tutorials/multimodal/object_detection/quick_start/tmp/ea97b4b870a24b65917cd62fd7296303-quick_start_tutorial_temp_save/epoch=20-step=42.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 23, global step 48: 'val_map' was not in top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 26, global step 54: 'val_map' reached 0.42527 (best 0.42527), saving model to '/home/ubuntu/ag/autogluon/docs/tutorials/multimodal/object_detection/quick_start/tmp/ea97b4b870a24b65917cd62fd7296303-quick_start_tutorial_temp_save/epoch=26-step=54.ckpt' as top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 29, global step 60: 'val_map' was not in top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 32, global step 66: 'val_map' was not in top 1
# Validation: 0it [00:00, ?it/s]
# Epoch 35, global step 72: 'val_map' was not in top 1
# AutoMM has created your model 🎉🎉🎉
#
# - To load the model, use the code below:
#     ```python
#     from autogluon.multimodal import MultiModalPredictor
#     predictor = MultiModalPredictor.load("/home/ubuntu/ag/autogluon/docs/tutorials/multimodal/object_detection/quick_start/tmp/ea97b4b870a24b65917cd62fd7296303-quick_start_tutorial_temp_save")
#     ```
#
# - You can open a terminal and launch Tensorboard to visualize the training log:
#     ```shell
#     # Assume you have installed tensorboard
#     tensorboard --logdir /home/ubuntu/ag/autogluon/docs/tutorials/multimodal/object_detection/quick_start/tmp/ea97b4b870a24b65917cd62fd7296303-quick_start_tutorial_temp_save
#     ```
#
# - If you are not satisfied with the model, try to increase the training time,
# adjust the hyperparameters (https://auto.gluon.ai/stable/tutorials/multimodal/advanced_topics/customization.html),
# or post issues on GitHub: https://github.com/autogluon/autogluon

# %% [markdown]
# Notice that at the end of each progress bar, if the checkpoint at current stage is saved,
# it prints the model's save path.
# In this example, it's `./quick_start_tutorial_temp_save`.
#
# Print out the time and we can see that it's fast!

# %%
print("This finetuning takes %.2f seconds." % (train_end - start))
# Out:
# This finetuning takes 455.17 seconds.

# %% [markdown]
# ## Evaluation
#
# To evaluate the model we just trained, run following code.
#
# And the evaluation results are shown in command line output.
# The first line is mAP in COCO standard, and the second line is mAP in VOC standard (or mAP50).
# For more details about these metrics, see [COCO's evaluation guideline](https://cocodataset.org/#detection-eval).
# Note that for presenting a fast finetuning we use presets "medium_quality",
# you could get better result on this dataset by simply using "high_quality" or "best_quality" presets,
# or customize your own model and hyperparameter settings: [Customization](../../advanced_topics/customization.ipynb), and some other examples at [Fast Fine-tune Coco](../finetune/detection_fast_finetune_coco) or [High Performance Fine-tune Coco](../finetune/detection_high_performance_finetune_coco).

# %%
predictor.evaluate(test_path)
eval_end = time.time()
# Out:
# Using default root folder: ./tiny_motorbike_coco/tiny_motorbike/Annotations/... Specify `root=...` if you feel it is wrong...
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Predicting: 0it [00:00, ?it/s]
# /opt/conda/envs/pytorch/lib/python3.9/site-packages/mmdet/structures/bbox/base_boxes.py:62: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1670525539683/work/torch/csrc/utils/tensor_new.cpp:230.)
#   data = torch.as_tensor(data)
# /opt/conda/envs/pytorch/lib/python3.9/site-packages/mmdet/structures/bbox/base_boxes.py:62: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1670525539683/work/torch/csrc/utils/tensor_new.cpp:230.)
#   data = torch.as_tensor(data)
# A new predictor save path is created.This is to prevent you to overwrite previous predictor saved here.You could check current save path at predictor._save_path.If you still want to use this path, set resume=True
# No path specified. Models will be saved in: "AutogluonModels/ag-20231020_195456/"
# saving file at /home/ubuntu/ag/autogluon/docs/tutorials/multimodal/object_detection/quick_start/AutogluonModels/ag-20231020_195456/object_detection_result_cache.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.09s).
# Accumulating evaluation results...
# DONE (t=0.04s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.372
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.528
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.394
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.295
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.475
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.758
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.254
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.429
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.451
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.385
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.546
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.823

# %% [markdown]
# Print out the evaluation time:

# %%
print("The evaluation takes %.2f seconds." % (eval_end - train_end))
# Out:
# The evaluation takes 3.43 seconds.

# %% [markdown]
# We can load a new predictor with previous save_path,
# and we can also reset the number of GPUs to use if not all the devices are available:

# %%
# Load and reset num_gpus
new_predictor = MultiModalPredictor.load(model_path)
new_predictor.set_num_gpus(1)
# Out:
# Load pretrained checkpoint: /home/ubuntu/ag/autogluon/docs/tutorials/multimodal/object_detection/quick_start/tmp/ea97b4b870a24b65917cd62fd7296303-quick_start_tutorial_temp_save/model.ckpt

# %% [markdown]
# Evaluating the new predictor gives us exactly the same result:

# %%
# Evaluate new predictor
new_predictor.evaluate(test_path)
# Out:
# Using default root folder: ./tiny_motorbike_coco/tiny_motorbike/Annotations/... Specify `root=...` if you feel it is wrong...
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Predicting: 0it [00:00, ?it/s]
# /opt/conda/envs/pytorch/lib/python3.9/site-packages/mmdet/structures/bbox/base_boxes.py:62: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1670525539683/work/torch/csrc/utils/tensor_new.cpp:230.)
#   data = torch.as_tensor(data)
# /opt/conda/envs/pytorch/lib/python3.9/site-packages/mmdet/structures/bbox/base_boxes.py:62: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1670525539683/work/torch/csrc/utils/tensor_new.cpp:230.)
#   data = torch.as_tensor(data)
# A new predictor save path is created.This is to prevent you to overwrite previous predictor saved here.You could check current save path at predictor._save_path.If you still want to use this path, set resume=True
# No path specified. Models will be saved in: "AutogluonModels/ag-20231020_195459/"
# saving file at /home/ubuntu/ag/autogluon/docs/tutorials/multimodal/object_detection/quick_start/AutogluonModels/ag-20231020_195459/object_detection_result_cache.json
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.09s).
# Accumulating evaluation results...
# DONE (t=0.04s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.372
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.528
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.394
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.295
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.475
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.758
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.254
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.429
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.451
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.385
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.546
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.823
# {'map': 0.3716289807875113,
#  'mean_average_precision': 0.3716289807875113,
#  'map_50': 0.5275681487129935,
#  'map_75': 0.3941585970973638,
#  'map_small': 0.29494713560448216,
#  'map_medium': 0.474669106835527,
#  'map_large': 0.7579065425977499,
#  'mar_1': 0.2536227390180878,
#  'mar_10': 0.42897110641296693,
#  'mar_100': 0.45061310782241015,
#  'mar_small': 0.3852083333333333,
#  'mar_medium': 0.5463492063492064,
#  'mar_large': 0.8232838506522716}

# %% [markdown]
# For how to set the hyperparameters and finetune the model with higher performance,
# see [AutoMM Detection - High Performance Finetune on COCO Format Dataset](../finetune/detection_high_performance_finetune_coco.ipynb).
#
# ## Inference
# Now that we have gone through the model setup, finetuning, and evaluation, this section details the inference.
# Specifically, we layout the steps for using the model to make predictions and visualize the results.
#
# To run inference on the entire test set, perform:

# %%
pred = predictor.predict(test_path)
print(pred)
# Out:
# Using default root folder: ./tiny_motorbike_coco/tiny_motorbike/Annotations/... Specify `root=...` if you feel it is wrong...
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Predicting: 0it [00:00, ?it/s]
# /opt/conda/envs/pytorch/lib/python3.9/site-packages/mmdet/structures/bbox/base_boxes.py:62: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1670525539683/work/torch/csrc/utils/tensor_new.cpp:230.)
#   data = torch.as_tensor(data)
# /opt/conda/envs/pytorch/lib/python3.9/site-packages/mmdet/structures/bbox/base_boxes.py:62: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1670525539683/work/torch/csrc/utils/tensor_new.cpp:230.)
#   data = torch.as_tensor(data)
#                                                 image  \
# 0   ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 1   ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 2   ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 3   ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 4   ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 5   ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 6   ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 7   ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 8   ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 9   ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 10  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 11  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 12  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 13  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 14  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 15  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 16  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 17  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 18  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 19  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 20  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 21  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 22  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 23  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 24  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 25  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 26  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 27  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 28  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 29  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 30  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 31  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 32  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 33  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 34  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 35  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 36  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 37  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 38  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 39  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 40  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 41  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 42  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 43  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 44  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 45  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 46  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 47  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 48  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
# 49  ./tiny_motorbike_coco/tiny_motorbike/Annotatio...
#
#                                                bboxes
# 0   [{'class': 'person', 'class_id': 8, 'bbox': [1...
# 1   [{'class': 'person', 'class_id': 8, 'bbox': [1...
# 2   [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 3   [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 4   [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 5   [{'class': 'person', 'class_id': 8, 'bbox': [2...
# 6   [{'class': 'person', 'class_id': 8, 'bbox': [1...
# 7   [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 8   [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 9   [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 10  [{'class': 'person', 'class_id': 8, 'bbox': [2...
# 11  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 12  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 13  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 14  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 15  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 16  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 17  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 18  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 19  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 20  [{'class': 'person', 'class_id': 8, 'bbox': [9...
# 21  [{'class': 'person', 'class_id': 8, 'bbox': [3...
# 22  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 23  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 24  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 25  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 26  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 27  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 28  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 29  [{'class': 'person', 'class_id': 8, 'bbox': [1...
# 30  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 31  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 32  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 33  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 34  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 35  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 36  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 37  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 38  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 39  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 40  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 41  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 42  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 43  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 44  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 45  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 46  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 47  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 48  [{'class': 'motorbike', 'class_id': 7, 'bbox':...
# 49  [{'class': 'motorbike', 'class_id': 7, 'bbox':...

# %% [markdown]
# The output `pred` is a `pandas` `DataFrame` that has two columns, `image` and `bboxes`.
#
# In `image`, each row contains the image path
#
# In `bboxes`, each row is a list of dictionaries, each one representing a bounding box: `{"class": <predicted_class_name>, "bbox": [x1, y1, x2, y2], "score": <confidence_score>}`
#
# Note that, by default, the `predictor.predict` does not save the detection results into a file.
#
# To run inference and save results, run the following:

# %%
pred = predictor.predict(test_path, save_results=True)
# Out:
# Using default root folder: ./tiny_motorbike_coco/tiny_motorbike/Annotations/... Specify `root=...` if you feel it is wrong...
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Predicting: 0it [00:00, ?it/s]
# /opt/conda/envs/pytorch/lib/python3.9/site-packages/mmdet/structures/bbox/base_boxes.py:62: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1670525539683/work/torch/csrc/utils/tensor_new.cpp:230.)
#   data = torch.as_tensor(data)
# /opt/conda/envs/pytorch/lib/python3.9/site-packages/mmdet/structures/bbox/base_boxes.py:62: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1670525539683/work/torch/csrc/utils/tensor_new.cpp:230.)
#   data = torch.as_tensor(data)
# A new predictor save path is created.This is to prevent you to overwrite previous predictor saved here.You could check current save path at predictor._save_path.If you still want to use this path, set resume=True
# No path specified. Models will be saved in: "AutogluonModels/ag-20231020_195505/"
# Saved detection results to /home/ubuntu/ag/autogluon/docs/tutorials/multimodal/object_detection/quick_start/AutogluonModels/ag-20231020_195505/result.txt

# %% [markdown]
# Here, we save `pred` into a `.txt` file, which exactly follows the same layout as in `pred`.
# You can use a predictor initialized in any way (i.e. finetuned predictor, predictor with pretrained model, etc.).
#
# ## Visualizing Results
# To run visualizations, ensure that you have `opencv` installed. If you haven't already, install `opencv` by running

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /opt/conda/envs/pytorch/lib/python3.9/site-packages (4.8.0.74)
# Requirement already satisfied: numpy>=1.17.0 in /opt/conda/envs/pytorch/lib/python3.9/site-packages (from opencv-python) (1.24.3)

# %% [markdown]
# To visualize the detection bounding boxes, run the following:

# %%
from autogluon.multimodal.utils import Visualizer

conf_threshold = 0.4  # Specify a confidence threshold to filter out unwanted boxes
image_result = pred.iloc[30]

img_path = image_result.image  # Select an image to visualize

visualizer = Visualizer(img_path)  # Initialize the Visualizer
out = visualizer.draw_instance_predictions(image_result, conf_threshold=conf_threshold)  # Draw detections
visualized = out.get_image()  # Get the visualized image

from PIL import Image
from IPython.display import display
img = Image.fromarray(visualized, 'RGB')
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x375>

# %% [markdown]
# ## Testing on Your Own Data
# You can also predict on your own images with various input format. The follow is an example:
#
# Download the example image:

# %%
from autogluon.multimodal import download
image_url = "https://raw.githubusercontent.com/dmlc/web-data/master/gluoncv/detection/street_small.jpg"
test_image = download(image_url)

# %% [markdown]
# Run inference on data in a dictionary of COCO format (See [Convert Data to COCO Format](../data_preparation/convert_data_to_coco_format.ipynb) for more details about COCO format.):

# %%
pred_test_image = predictor.predict({"image": [test_image]})
print(pred_test_image)
# Out:
# Predicting: 0it [00:00, ?it/s]
# /opt/conda/envs/pytorch/lib/python3.9/site-packages/mmdet/structures/bbox/base_boxes.py:62: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1670525539683/work/torch/csrc/utils/tensor_new.cpp:230.)
#   data = torch.as_tensor(data)
#               image                                             bboxes
# 0  street_small.jpg  [{'class': 'person', 'class_id': 8, 'bbox': [2...

# %% [markdown]
# Run inference on data in a json file of COCO format:

# %%
import json

# create a input file for demo
data = {"image": [test_image]}
input_file = "input_data_for_demo_in_tutorial.json"
with open(input_file, "w+") as f:
    json.dump(data, f)

pred_test_image = predictor.predict(input_file)
print(pred_test_image)
# Out:
# Using default root folder: ... Specify `root=...` if you feel it is wrong...
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:9                                                                                    │
# │                                                                                                  │
# │    6 with open(input_file, "w+") as f:                                                           │
# │    7 │   json.dump(data, f)                                                                      │
# │    8                                                                                             │
# │ ❱  9 pred_test_image = predictor.predict(input_file)                                             │
# │   10 print(pred_test_image)                                                                      │
# │   11                                                                                             │
# │                                                                                                  │
# │ /opt/conda/envs/pytorch/lib/python3.9/site-packages/autogluon/multimodal/predictor.py:2158 in    │
# │ predict                                                                                          │
# │                                                                                                  │
# │   2155 │   │                                                                                     │
# │   2156 │   │   self._ensure_inference_ready()                                                    │
# │   2157 │   │   if self._problem_type == OBJECT_DETECTION:                                        │
# │ ❱ 2158 │   │   │   data = object_detection_data_to_df(data)                                      │
# │   2159 │   │   │                                                                                 │
# │   2160 │   │   │   if self._label_column not in data:                                            │
# │   2161 │   │   │   │   self._label_column = None                                                 │
# │                                                                                                  │
# │ /opt/conda/envs/pytorch/lib/python3.9/site-packages/autogluon/multimodal/utils/object_detection. │
# │ py:170 in object_detection_data_to_df                                                            │
# │                                                                                                  │
# │    167 │   │   return from_list(data)                                                            │
# │    168 │   if isinstance(data, str):                                                             │
# │    169 │   │   if os.path.isdir(data) or data.endswith(".json"):                                 │
# │ ❱  170 │   │   │   return from_coco_or_voc(data)                                                 │
# │    171 │   │   return from_str(data)                                                             │
# │    172 │   if isinstance(data, pd.DataFrame):                                                    │
# │    173 │   │   sanity_check_dataframe(data)                                                      │
# │                                                                                                  │
# │ /opt/conda/envs/pytorch/lib/python3.9/site-packages/autogluon/multimodal/utils/object_detection. │
# │ py:1170 in from_coco_or_voc                                                                      │
# │                                                                                                  │
# │   1167 │   │   # VOC use dir as input                                                            │
# │   1168 │   │   return from_voc(root=file_path, splits=splits)                                    │
# │   1169 │   else:                                                                                 │
# │ ❱ 1170 │   │   return from_coco(file_path)                                                       │
# │   1171                                                                                           │
# │   1172                                                                                           │
# │   1173 def get_coco_format_classes(sample_data_path: str):                                       │
# │                                                                                                  │
# │ /opt/conda/envs/pytorch/lib/python3.9/site-packages/autogluon/multimodal/utils/object_detection. │
# │ py:760 in from_coco                                                                              │
# │                                                                                                  │
# │    757 │   │   raise ValueError("Unable to parse root: {}".format(root))                         │
# │    758 │                                                                                         │
# │    759 │   # synsets                                                                             │
# │ ❱  760 │   classes = [c["name"] for c in coco.loadCats(coco.getCatIds())]                        │
# │    761 │   # load entries                                                                        │
# │    762 │   d = {"image": [], "rois": []}                                                         │
# │    763 │   image_ids = sorted(coco.getImgIds())                                                  │
# │                                                                                                  │
# │ /opt/conda/envs/pytorch/lib/python3.9/site-packages/pycocotools/coco.py:168 in getCatIds         │
# │                                                                                                  │
# │   165 │   │   catIds = catIds if _isArrayLike(catIds) else [catIds]                              │
# │   166 │   │                                                                                      │
# │   167 │   │   if len(catNms) == len(supNms) == len(catIds) == 0:                                 │
# │ ❱ 168 │   │   │   cats = self.dataset['categories']                                              │
# │   169 │   │   else:                                                                              │
# │   170 │   │   │   cats = self.dataset['categories']                                              │
# │   171 │   │   │   cats = cats if len(catNms) == 0 else [cat for cat in cats if cat['name']       │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyError: 'categories'

# %% [markdown]
# Run inference on data in a list of image file names:

# %%
pred_test_image = predictor.predict([test_image])
print(pred_test_image)
# Out:
# Predicting: 0it [00:00, ?it/s]
# /opt/conda/envs/pytorch/lib/python3.9/site-packages/mmdet/structures/bbox/base_boxes.py:62: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1670525539683/work/torch/csrc/utils/tensor_new.cpp:230.)
#   data = torch.as_tensor(data)
#               image                                             bboxes
# 0  street_small.jpg  [{'class': 'person', 'class_id': 8, 'bbox': [2...

# %% [markdown]
# ## Other Examples
#
# You may go to [AutoMM Examples](https://github.com/autogluon/autogluon/tree/master/examples/automm) to explore other examples about AutoMM.
#
# ## Customization
# To learn how to customize AutoMM, please refer to [Customize AutoMM](../../advanced_topics/customization.ipynb).
#
# ## Citation

# %% [markdown]
# ```
# @article{DBLP:journals/corr/abs-2107-08430,
#   author    = {Zheng Ge and
#                Songtao Liu and
#                Feng Wang and
#                Zeming Li and
#                Jian Sun},
#   title     = {{YOLOX:} Exceeding {YOLO} Series in 2021},
#   journal   = {CoRR},
#   volume    = {abs/2107.08430},
#   year      = {2021},
#   url       = {https://arxiv.org/abs/2107.08430},
#   eprinttype = {arXiv},
#   eprint    = {2107.08430},
#   timestamp = {Tue, 05 Apr 2022 14:09:44 +0200},
#   biburl    = {https://dblp.org/rec/journals/corr/abs-2107-08430.bib},
#   bibsource = {dblp computer science bibliography, https://dblp.org},
# }
# ```
